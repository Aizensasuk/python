# %%
print(10+5*2)
# Out:
# 20

# %%
print((10+5)*2)
# Out:
# 30

# %%
print(20-4**2)
# Out:
# 4

# %%
print(100//5*2)
# Out:
# 40

# %%
print(18%5+2)
# Out:
# 5

# %%
print(2**3**2)
# Out:
# 512

# %%
print(4**2**3)
# Out:
# 65536

# %%
print(16//2**2)
# Out:
# 4

# %%
print(9+6*2**2)
# Out:
# 33

# %%
print(8-2**2*2)
# Out:
# 0

# %%
print(10>5 and 5>2)
# Out:
# True

# %%
print(10>5 or 5<2)
# Out:
# True

# %%
print(not 10>5)
# Out:
# False

# %%
print(True or False and False)
# Out:
# True

# %%
print(5<10<20)
# Out:
# True

# %%
x=5
x=x+3*2
print(x)
# Out:
# 8

# %%
x=10
x*=2+3
print(x)
# Out:
# 50

# %%
x=5
x=x==5
print(x)
# Out:
# True

# %%
x=2
x**=2+1
print(x)
# Out:
# 8

# %%
x=1
x+=x==1
print(x)
# Out:
# 2

# %%
print(5 and 0 or 8)
# Out:
# 8

# %%
print(0 or 5 and 8)
# Out:
# 8

# %%
print(True==False or True)
# Out:
# True

# %%
print(False==False and False )
# Out:
# False

# %%
print(not True == False)
# Out:
# True

# %%
#1
a="hello"
b="e"
if b in a :
    print("e is present in the str")
# Out:
# e is present in the str

# %%
#2
for i in range(1,12,2):
    if i%7==0:
          print(i ,"7 is a prime no.")
# Out:
# 7 7 is a prime no.

# %%
#3 
word=input("enter your word")
word_1=["alice","bob","john123"]
if word in word_1:
    print("username already taken")
# Out:
# enter your word john123
# username already taken

# %%
#4
word="sun"
sentence="the sun rises in the east"
if  word in sentence:
    print("sun prsent in the senetence")
# Out:
# sun prsent in the senetence

# %%
#5
item="milk"
cart=["bread","eggs"]
if item is not cart:
    print("milk was not in cart")
    
print("added now")
# Out:
# milk was not in cart
# added now

# %%
#1
a=[1,2]
b=a
if a==b:
    print("a and b refer to the same object")
# Out:
# a and b refer to the same object

# %%
list1=[1,2,3]
list2=[1,2,3]
if list1!=list2:
    print(" ist and 2 do not refer to same object")
elif list1==list2:
    print("")

# %%
#3
#4 not done

# %%
#5
str1="apple"
str2= "".join(\["a","p","p","i","e"])
if str1==str2:
    print("str1 and str2 have the same value but are not the same object")
# Out:
#   Cell In[80], line 3
#     str2= "".join(\["a","p","p","i","e"])
#                    ^
# SyntaxError: unexpected character after line continuation character
