# %%
#first question
print("python\nis\nfun")
# Out:
# python
# is
# fun

# %%
#second question
a=25
b=25.5
c=True
d="String"
e=2+5j
print(type(a),a)
print(type(b),b)
print(type(c),c)
print(type(d),d)
print(type(e),e)
# Out:
# <class 'int'> 25
# <class 'float'> 25.5
# <class 'bool'> True
# <class 'str'> String
# <class 'complex'> (2+5j)

# %%
#third question
x=True 
y=None
print(type(x))
print(type(y))
# Out:
# <class 'bool'>
# <class 'NoneType'>

# %%
#fifth
name="sachin"
roll_no=25
percentage=12
print(f'my name is {name} roll no is {roll_no} percentage{percentage}')
# Out:
# my name is sachin roll no is 25 percentage12

# %%
#last question
it1=eval(input("enter your item1 price"))
it2=eval(input("enter second item2 price"))
it3=eval(input("enter your third item3 price"))
it4=eval(input("enter your fourth item4 price"))
it5=eval(input("enter fifth item5 price"))
total_item=it1+it2+it3+it4+it5
gst=total_item*(5/100)
print("first item",it1)
print("second item",it2)
print("third item",it3)
print("forth item",it4)
print("fifth item",it5)
print("total item price",total_item)
print("gst on it",gst)
